# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
data=pd.read_csv('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Matplotlib/02-BarCharts/data.csv')

# %%
data.columns
# Out:
# Index(['Responder_id', 'LanguagesWorkedWith'], dtype='object')

# %%
ids=data['Responder_id']
lang= data['LanguagesWorkedWith']

# %%
lcount=Counter()
for i in lang:
    lcount.update(i.split(';'))

# %%
language=list(new.keys())
popularity=list(new.values())

# %%
new=dict(lcount)

# %%
df=pd.DataFrame(list(zip(language,popularity)),columns=['Language','Popularity'])
df=df.sort_values(by=['Popularity'])

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
plt.barh(df['Language'],df['Popularity'])
plt.xlabel('Popularity')
plt.title('Most Popular Programming Langauge ')
# Out:
# Text(0.5, 1.0, 'Most Popular Programming Langauge ')
